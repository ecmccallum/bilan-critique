# %% [markdown]
# # 01_emissions_extraction.ipynb
# **Author:** Emma McCallum
# **Purpose:** Extract and restructure BEGES emissions categories for five firms
# **Input:** data/processed/five_firms_full.csv
# **Output:** data/processed/emissions_long.csv, firm_summary.csv

# %%
import pandas as pd

df = pd.read_csv("../data/processed/five_firms_full.csv")

print(f"Rows: {len(df)}")
print(f"Columns: {len(df.columns)}")
# Out:
# Rows: 7
# Columns: 104

# %%
# Which firms and reporting years do we have?
df[["Raison sociale", "Année de reporting"]].sort_values("Raison sociale")
# Out:
#                 Raison sociale  Année de reporting
# 0                 ANTEA FRANCE                2019
# 1                 ANTEA FRANCE                2023
# 2                      ARTELIA                2022
# 3  BUREAU VERITAS EXPLOITATION                2019
# 4  BUREAU VERITAS EXPLOITATION                2023
# 5                   ECOCERT SA                2024
# 6                      Eco CO2                2023

# %% [markdown]
# ## Note: multi-year data available for two firms
#
# ANTEA FRANCE has reports for 2019 and 2023.
# BUREAU VERITAS EXPLOITATION has reports for 2019 and 2023.
#
# For the main cross-firm analysis we use the most recent report per firm.
# The 2019 reports are preserved in the raw data for a within-firm
# evolution analysis in a later notebook or as a bonus section.
#
# Potential question: did their Scope 3 coverage improve between 2019 and 2023?

# %%
# Keep only the most recent report per firm
df_recent = df.sort_values("Année de reporting", ascending=False)
df_recent = df_recent.drop_duplicates(subset="Raison sociale", keep="first")
df_recent = df_recent.sort_values("Raison sociale").reset_index(drop=True)

df_recent[["Raison sociale", "Année de reporting"]]
# Out:
#                 Raison sociale  Année de reporting
# 0                 ANTEA FRANCE                2023
# 1                      ARTELIA                2022
# 2  BUREAU VERITAS EXPLOITATION                2023
# 3                   ECOCERT SA                2024
# 4                      Eco CO2                2023

# %%
# Find all emissions columns
emissions_cols = [col for col in df_recent.columns if col.startswith("Emissions publication")]
print(f"Number of emissions columns: {len(emissions_cols)}")
print("\nColumn names:")
for col in emissions_cols:
    print(col)
# Out:
# Number of emissions columns: 22
#
# Column names:
# Emissions publication P1.1
# Emissions publication P1.2
# Emissions publication P1.3
# Emissions publication P1.4
# Emissions publication P1.5
# Emissions publication P2.1
# Emissions publication P2.2
# Emissions publication P3.1
# Emissions publication P3.2
# Emissions publication P3.3
# Emissions publication P3.4
# Emissions publication P3.5
# Emissions publication P4.1
# Emissions publication P4.2
# Emissions publication P4.3
# Emissions publication P4.4
# Emissions publication P4.5
# Emissions publication P5.1
# Emissions publication P5.2
# Emissions publication P5.3
# Emissions publication P5.4
# Emissions publication P6.1

# %% [markdown]
# # BEGES Emissions Category Structure and GHG Protocol Mapping
#
# **Sources**
# - ADEME: https://bilans-ges.ademe.fr/ressources/points-cles-methodologiques
# - ADEME: *Méthode pour la réalisation des bilans d'émissions de GES*, Version 4, Octobre 2016
# - GHG Protocol Corporate Standard, revised edition 2004, Chapter 4
# - GHG Protocol Corporate Value Chain (Scope 3) Standard, 2011, Chapter 5 Table 5.3
# - ISO TR 14069: *Guide d'application de la norme ISO 14064-1*
#
# ---
#
# The BEGES framework defines **3 regulatory categories** and **23 posts**, in accordance
# with ISO 14064-1. Categories 1 and 2 (posts 1–7) are mandatory. Category 3 (posts 8–23)
# is recommended but not obligatory under the regulation. For publication and export, the
# ADEME platform groups the 23 posts into **6 P-categories**. These are two separate
# organisational schemes for the same underlying data.
#
# The mapping between BEGES posts and GHG Protocol Scope 3 categories is approximate,
# not identical. A full post-level cross-reference is built in notebook 02 using the ADEME
# methodology document as the primary reference.
#
# ---
#
# ## BEGES regulatory categories and posts
#
# **Category 1 — Émissions directes** | ≈ Scope 1 | MANDATORY | Posts 1–5
#
# | Post | Name |
# |------|------|
# | 1 | Émissions directes des sources fixes de combustion |
# | 2 | Émissions directes des sources mobiles à moteur thermique |
# | 3 | Émissions directes des procédés hors énergie |
# | 4 | Émissions directes fugitives |
# | 5 | Émissions issues de la biomasse (sols et forêts) |
#
# **Category 2 — Émissions indirectes associées à l'énergie** | ≈ Scope 2 | MANDATORY | Posts 6–7
#
# | Post | Name |
# |------|------|
# | 6 | Émissions indirectes liées à la consommation d'électricité |
# | 7 | Émissions indirectes liées à la consommation de vapeur, chaleur ou froid |
#
# **Category 3 — Autres émissions indirectes** | ≈ Scope 3 | RECOMMENDED | Posts 8–23
#
# | Post | Name |
# |------|------|
# | 8 | Émissions liées à l'énergie non incluses dans les catégories 1 et 2 |
# | 9 | Achats de produits ou services |
# | 10 | Immobilisations de biens |
# | 11 | Déchets |
# | 12 | Transport de marchandises amont |
# | 13 | Déplacements professionnels |
# | 14 | Actifs en leasing amont |
# | 15 | Investissements |
# | 16 | Transport des visiteurs et des clients |
# | 17 | Transport de marchandises aval |
# | 18 | Utilisation des produits vendus |
# | 19 | Fin de vie des produits vendus |
# | 20 | Franchise aval |
# | 21 | Leasing aval |
# | 22 | Déplacements domicile-travail |
# | 23 | Autres émissions indirectes |
#
# ---
#
# ## ADEME export: P-category groupings
#
# | P category | Regulatory category | Posts | GHG Protocol ≈ |
# |------------|-------------------|-------|----------------|
# | P1 — Émissions directes | Category 1 | 1–5 | Scope 1 |
# | P2 — Émissions indirectes associées à l'énergie | Category 2 | 6–7 | Scope 2 |
# | P3 — Émissions indirectes associées au transport | Category 3 | 12, 13, 16, 17, 22 | Scope 3 Cat 4, 6, 7, 9 |
# | P4 — Émissions indirectes associées aux produits achetés | Category 3 | 8, 9, 10, 11, 14 | Scope 3 Cat 1, 2, 3, 5, 8 |
# | P5 — Émissions indirectes associées aux produits vendus | Category 3 | 18, 19, 20, 21 | Scope 3 Cat 11, 12, 13, 14 |
# | P6 — Autres émissions indirectes | Category 3 | 15, 23 | Scope 3 Cat 15 and autres émissions indirectes |
#
# ---
#
# ## GHG Protocol Scope 3: 15 categories
#
# Official structure from *Corporate Value Chain (Scope 3) Standard*, Table 5.3.
#
# **Upstream**
#
# | Cat | Name |
# |-----|------|
# | 1 | Purchased goods and services |
# | 2 | Capital goods |
# | 3 | Fuel and energy related activities |
# | 4 | Upstream transportation and distribution |
# | 5 | Waste generated in operations |
# | 6 | Business travel |
# | 7 | Employee commuting |
# | 8 | Upstream leased assets |
#
# **Downstream**
#
# | Cat | Name |
# |-----|------|
# | 9 | Downstream transportation and distribution |
# | 10 | Processing of sold products |
# | 11 | Use of sold products |
# | 12 | End of life treatment of sold products |
# | 13 | Downstream leased assets |
# | 14 | Franchises |
# | 15 | Investments |
#
# **Note:** GHG Protocol Category 10 (Processing of sold products) has no direct BEGES
# equivalent. It will appear as a structural gap in the notebook 02 coverage matrix.
#
# ---

# %%
# Extract all emissions columns for the five firms
emissions_cols = [col for col in df_recent.columns 
                  if col.startswith("Emissions publication")]

# Build a clean emissions dataframe with firm name and year
df_emissions = df_recent[["Raison sociale", "Année de reporting"] + emissions_cols].copy()

# Rename columns to shorter names for easier working
rename_map = {col: col.replace("Emissions publication ", "") 
              for col in emissions_cols}
df_emissions = df_emissions.rename(columns=rename_map)

print(df_emissions.shape)
df_emissions
# Out:
# (5, 24)
#                 Raison sociale  Année de reporting    P1.1     P1.2  P1.3  \
# 0                 ANTEA FRANCE                2023  104.30  1820.50   0.0
# 1                      ARTELIA                2022    5.00  3088.00   0.0
# 2  BUREAU VERITAS EXPLOITATION                2023    0.00   136.00   0.0
# 3                   ECOCERT SA                2024    0.00   565.30   0.0
# 4                      Eco CO2                2023   13.11    13.31   0.0
#
#     P1.4  P1.5    P2.1    P2.2   P3.1  ...     P4.1     P4.2   P4.3    P4.4  \
# 0    0.0   0.0   44.40    0.00  11.50  ...  1283.30  1331.40  63.70  1315.5
# 1  272.0   0.0  649.00  332.00   0.00  ...  1966.00  5047.00  38.00     0.0
# 2   94.0   0.0    0.00    0.00   0.00  ...  4912.00   395.00  62.00     0.0
# 3    0.0   0.0   12.10    0.00  90.40  ...   362.00   329.80   0.80   396.4
# 4    0.0   0.0    0.31    1.11   0.15  ...  1353.04    78.63   0.23     0.0
#
#        P4.5  P5.1  P5.2  P5.3  P5.4   P6.1
# 0   8162.90  0.00   0.0  0.00   0.0   0.00
# 1      0.00  0.00   0.0  0.00   0.0   0.00
# 2  16446.00  0.00   0.0  0.00   0.0   0.00
# 3    981.70  0.00   0.0  0.00   0.0   0.00
# 4      3.48  0.45   0.0  0.63   0.0  21.64
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Wide to long format transformation
#
# Currently the data is in wide format: one row per firm, one column per emissions category.
# For analysis and visualisation we need long format: one row per firm per category.
# This makes it easy to filter, group, and plot by category or by scope.
# We use pandas melt() to do this transformation.

# %%
# Transform from wide to long format
df_long = df_emissions.melt(
    id_vars=["Raison sociale", "Année de reporting"],
    var_name="beges_category",
    value_name="tco2e"
)

print(f"Rows in long format: {len(df_long)}")
df_long.head(10)
# Out:
# Rows in long format: 110
#                 Raison sociale  Année de reporting beges_category    tco2e
# 0                 ANTEA FRANCE                2023           P1.1   104.30
# 1                      ARTELIA                2022           P1.1     5.00
# 2  BUREAU VERITAS EXPLOITATION                2023           P1.1     0.00
# 3                   ECOCERT SA                2024           P1.1     0.00
# 4                      Eco CO2                2023           P1.1    13.11
# 5                 ANTEA FRANCE                2023           P1.2  1820.50
# 6                      ARTELIA                2022           P1.2  3088.00
# 7  BUREAU VERITAS EXPLOITATION                2023           P1.2   136.00
# 8                   ECOCERT SA                2024           P1.2   565.30
# 9                      Eco CO2                2023           P1.2    13.31

# %%
# Map each BEGES P-category to GHG Protocol scope equivalent
# Source: ADEME Méthode BEGES V4, 2016 and ADEME export documentation
scope_map = {
    "P1.1": "Scope 1", "P1.2": "Scope 1", "P1.3": "Scope 1",
    "P1.4": "Scope 1", "P1.5": "Scope 1",
    "P2.1": "Scope 2", "P2.2": "Scope 2",
    "P3.1": "Scope 3", "P3.2": "Scope 3", "P3.3": "Scope 3",
    "P3.4": "Scope 3", "P3.5": "Scope 3",
    "P4.1": "Scope 3", "P4.2": "Scope 3", "P4.3": "Scope 3",
    "P4.4": "Scope 3", "P4.5": "Scope 3",
    "P5.1": "Scope 3", "P5.2": "Scope 3", "P5.3": "Scope 3",
    "P5.4": "Scope 3",
    "P6.1": "Scope 3"
}

# Add mandatory vs recommended flag
mandatory_map = {
    "P1.1": "Mandatory", "P1.2": "Mandatory", "P1.3": "Mandatory",
    "P1.4": "Mandatory", "P1.5": "Mandatory",
    "P2.1": "Mandatory", "P2.2": "Mandatory",
    "P3.1": "Recommended", "P3.2": "Recommended", "P3.3": "Recommended",
    "P3.4": "Recommended", "P3.5": "Recommended",
    "P4.1": "Recommended", "P4.2": "Recommended", "P4.3": "Recommended",
    "P4.4": "Recommended", "P4.5": "Recommended",
    "P5.1": "Recommended", "P5.2": "Recommended", "P5.3": "Recommended",
    "P5.4": "Recommended",
    "P6.1": "Recommended"
}

df_long["scope"] = df_long["beges_category"].map(scope_map)
df_long["regulatory_status"] = df_long["beges_category"].map(mandatory_map)

print(df_long["scope"].value_counts())
df_long.head(10)
# Out:
# scope
# Scope 3    75
# Scope 1    25
# Scope 2    10
# Name: count, dtype: int64
#                 Raison sociale  Année de reporting beges_category    tco2e  \
# 0                 ANTEA FRANCE                2023           P1.1   104.30
# 1                      ARTELIA                2022           P1.1     5.00
# 2  BUREAU VERITAS EXPLOITATION                2023           P1.1     0.00
# 3                   ECOCERT SA                2024           P1.1     0.00
# 4                      Eco CO2                2023           P1.1    13.11
# 5                 ANTEA FRANCE                2023           P1.2  1820.50
# 6                      ARTELIA                2022           P1.2  3088.00
# 7  BUREAU VERITAS EXPLOITATION                2023           P1.2   136.00
# 8                   ECOCERT SA                2024           P1.2   565.30
# 9                      Eco CO2                2023           P1.2    13.31
#
#      scope regulatory_status
# 0  Scope 1         Mandatory
# 1  Scope 1         Mandatory
# 2  Scope 1         Mandatory
# 3  Scope 1         Mandatory
# 4  Scope 1         Mandatory
# 5  Scope 1         Mandatory
# 6  Scope 1         Mandatory
# 7  Scope 1         Mandatory
# 8  Scope 1         Mandatory
# 9  Scope 1         Mandatory

# %%
# Total emissions per firm per scope
scope_totals = df_long.groupby(
    ["Raison sociale", "Année de reporting", "scope"]
)["tco2e"].sum().reset_index()

scope_totals = scope_totals.rename(columns={"tco2e": "total_tco2e"})
scope_totals["total_tco2e"] = scope_totals["total_tco2e"].round(1)

scope_totals
# Out:
#                  Raison sociale  Année de reporting    scope  total_tco2e
# 0                  ANTEA FRANCE                2023  Scope 1       1924.8
# 1                  ANTEA FRANCE                2023  Scope 2         44.4
# 2                  ANTEA FRANCE                2023  Scope 3      12840.8
# 3                       ARTELIA                2022  Scope 1       3365.0
# 4                       ARTELIA                2022  Scope 2        981.0
# 5                       ARTELIA                2022  Scope 3      17944.0
# 6   BUREAU VERITAS EXPLOITATION                2023  Scope 1        230.0
# 7   BUREAU VERITAS EXPLOITATION                2023  Scope 2          0.0
# 8   BUREAU VERITAS EXPLOITATION                2023  Scope 3      23068.0
# 9                    ECOCERT SA                2024  Scope 1        565.3
# 10                   ECOCERT SA                2024  Scope 2         12.1
# 11                   ECOCERT SA                2024  Scope 3       3183.6
# 12                      Eco CO2                2023  Scope 1         26.4
# 13                      Eco CO2                2023  Scope 2          1.4
# 14                      Eco CO2                2023  Scope 3       1535.6

# %%
# Calculate scope totals per firm including Scope 1, Scope 2, Scope 3-equivalent
firm_totals = scope_totals.groupby("Raison sociale")["total_tco2e"].sum().reset_index()
firm_totals = firm_totals.rename(columns={"total_tco2e": "grand_total"})

# Pivot to get Scope 1, 2, 3 as separate columns
scope_pivot = scope_totals.pivot(index="Raison sociale", columns="scope", values="total_tco2e").reset_index()
scope_pivot.columns.name = None
scope_pivot = scope_pivot.rename(columns={
    "Scope 1": "scope1_total",
    "Scope 2": "scope2_total",
    "Scope 3": "scope3_total"
})

# Add reporting year
year_map = df_recent.set_index("Raison sociale")["Année de reporting"].to_dict()

firm_summary = firm_totals.merge(scope_pivot, on="Raison sociale")
firm_summary["scope3_pct"] = (
    firm_summary["scope3_total"] / firm_summary["grand_total"] * 100
).round(1)
firm_summary["reporting_year"] = firm_summary["Raison sociale"].map(year_map)
firm_summary = firm_summary.sort_values("scope3_pct", ascending=False)

# Reorder columns
firm_summary = firm_summary[[
    "Raison sociale", "reporting_year", "scope1_total",
    "scope2_total", "scope3_total", "grand_total", "scope3_pct"
]]

firm_summary
# Out:
#                 Raison sociale  reporting_year  scope1_total  scope2_total  \
# 2  BUREAU VERITAS EXPLOITATION            2023         230.0           0.0
# 4                      Eco CO2            2023          26.4           1.4
# 0                 ANTEA FRANCE            2023        1924.8          44.4
# 3                   ECOCERT SA            2024         565.3          12.1
# 1                      ARTELIA            2022        3365.0         981.0
#
#    scope3_total  grand_total  scope3_pct
# 2       23068.0      23298.0        99.0
# 4        1535.6       1563.4        98.2
# 0       12840.8      14810.0        86.7
# 3        3183.6       3761.0        84.6
# 1       17944.0      22290.0        80.5

# %%
# Add headcount for emissions intensity calculation
headcount_col = "Nombre de salariés/d'agents de l'ensemble des SIREN déclarés sur ce bilan lors de l'année de reporting du bilan"

df_headcount = df_recent[["Raison sociale", headcount_col]].copy()
df_headcount = df_headcount.rename(columns={headcount_col: "headcount"})
df_headcount["headcount"] = pd.to_numeric(df_headcount["headcount"], errors="coerce")

firm_summary = firm_summary.merge(df_headcount, on="Raison sociale")
firm_summary["tco2e_per_employee"] = (
    firm_summary["scope3_total"] / firm_summary["headcount"]
).round(1)

firm_summary
# Out:
#                 Raison sociale  reporting_year  scope1_total  scope2_total  \
# 0  BUREAU VERITAS EXPLOITATION            2023         230.0           0.0
# 1                      Eco CO2            2023          26.4           1.4
# 2                 ANTEA FRANCE            2023        1924.8          44.4
# 3                   ECOCERT SA            2024         565.3          12.1
# 4                      ARTELIA            2022        3365.0         981.0
#
#    scope3_total  grand_total  scope3_pct  headcount  tco2e_per_employee
# 0       23068.0      23298.0        99.0        NaN                 NaN
# 1        1535.6       1563.4        98.2        NaN                 NaN
# 2       12840.8      14810.0        86.7        NaN                 NaN
# 3        3183.6       3761.0        84.6      778.0                 4.1
# 4       17944.0      22290.0        80.5        NaN                 NaN

# %% [markdown]
# ## Note on headcount data
#
# Headcount was missing from the ADEME export for four of the five firms.
# ECOCERT SA is the only firm with headcount data available in the dataset:
# 778 employees, 2024, giving 4.1 tCO2e Scope 3 per employee.
#
# For the remaining four firms, headcount data was not available in the ADEME export.
# Emissions intensity per employee cannot be calculated for those firms without
# sourcing headcount from external sources such as company annual reports.
# This is flagged as a data quality limitation. Notebook 03 will revisit this
# when reviewing the methodology fields of each firm's published BEGES report.

# %% [markdown]
# ## Note on BEGES P6.1
#
# P6.1 in the ADEME open-data export is inferred to correspond to to BEGES posts 15 (Investissements)
# and 23 (Autres émissions indirectes). These are genuine indirect emissions and are
# included in the Scope 3-equivalent total alongside P3, P4, and P5. This assignment is inferred from the export structure and has not been verified against individual firm reports. It will be confirmed in notebook 03.
#
# The ADEME export contains a separate field, "Des émissions évitées ont été calculées
# pour", which is where avoided emissions are recorded. P6.1 is not that field.
#
# Eco CO2 is the only firm in this dataset with a non-zero P6.1 value (21.64 tCO2e).
# This is included in their Scope 3-equivalent total. The nature of this entry will be
# examined further in notebook 03 when reviewing free-text methodology fields.

# %%
# Save long format dataframe (all 22 emission categories including P6.1)
df_long.to_csv("../data/processed/emissions_long.csv", index=False)
print("Saved emissions_long.csv")

# Save corrected firm summary
firm_summary.to_csv("../data/processed/firm_summary.csv", index=False)


print("Saved firm_summary.csv")
# Out:
# Saved emissions_long.csv
# Saved firm_summary.csv

# %%
import os

files = [
    "../data/processed/emissions_long.csv",
    "../data/processed/firm_summary.csv"
]

for f in files:
    exists = os.path.exists(f)
    print(f"{f}: {'OK' if exists else 'MISSING'}")
# Out:
# ../data/processed/emissions_long.csv: OK
# ../data/processed/firm_summary.csv: OK

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

# Build pivot table for stacked bar: firms as rows, scopes as columns
# P6.1 is included as Scope 3-equivalent (posts 15 and 23: investments and other indirect emissions)

pivot = df_long.groupby(["Raison sociale", "scope"])["tco2e"].sum().unstack("scope")

# Ensure column order: Scope 1, Scope 2, Scope 3
pivot = pivot[["Scope 1", "Scope 2", "Scope 3"]]

# Sort firms by total descending so the biggest emitter is on the left
pivot["total"] = pivot.sum(axis=1)
pivot = pivot.sort_values("total", ascending=False).drop(columns="total")

# Shorten firm names for the x-axis
name_map = {
    "BUREAU VERITAS EXPLOITATION": "Bureau Veritas",
    "ANTEA FRANCE": "Antea France",
    "ARTELIA": "Artelia",
    "ECOCERT SA": "Ecocert SA",
    "Eco CO2": "Eco CO2",
}
pivot.index = pivot.index.map(name_map)

# Colours: muted green palette, lightest for S1, darkest for S3
colours = ["#a8c5a0", "#5a8f5a", "#2d5a2d"]

fig, ax = plt.subplots(figsize=(10, 6))

pivot.plot(
    kind="bar",
    stacked=True,
    ax=ax,
    color=colours,
    width=0.55,
    edgecolor="white",
    linewidth=0.6,
)

# Axis formatting
ax.set_xlabel("")
ax.set_ylabel("tCO₂e", fontsize=11)
ax.set_title(
    "Self-reported GHG emissions by firm and BEGES category\n"
"Stacked by scope equivalent from ADEME publication categories, most recent filing per firm",
    fontsize=12,
    pad=14,
)
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{x:,.0f}"))
ax.tick_params(axis="x", rotation=20, labelsize=10)
ax.tick_params(axis="y", labelsize=9)

# Add value labels on each segment (only if > 100 tCO2e to avoid clutter)
for bar_group in ax.containers:
    for bar in bar_group:
        h = bar.get_height()
        if h > 100:
            ax.text(
                bar.get_x() + bar.get_width() / 2,
                bar.get_y() + h / 2,
                f"{h:,.0f}",
                ha="center",
                va="center",
                fontsize=8,
                color="white",
                fontweight="bold",
            )

# Legend
ax.legend(
    title="Scope",
    loc="upper right",
    framealpha=0.8,
    fontsize=9,
    title_fontsize=9,
)

ax.spines[["top", "right"]].set_visible(False)

plt.tight_layout()
import os
os.makedirs("../figures", exist_ok=True)
plt.savefig("../figures/01_emissions_by_scope.png", dpi=150, bbox_inches="tight")
plt.show()
print("Saved to figures/01_emissions_by_scope.png")
# Out:
# Saved to figures/01_emissions_by_scope.png

# %% [markdown]
# ## Findings: emissions by scope across five firms
#
# The stacked bar chart reveals a consistent structural pattern across all five firms:
# Scope 3 is the dominant emissions category in every case, ranging from 80.5% (Artelia)
# to 99.0% (Bureau Veritas Exploitation). This pattern is plausible for service-sector firms,
# where direct combustion and purchased energy may represent only a small share of total climate impact. It also has an important methodological implication: the quality of each firm’s reported footprint depends largely on how completely and transparently indirect emissions have been measured, categorized, and disclosed.
#
# | Organisation | Year | Scope 1 (tCO2e) | Scope 2 (tCO2e) | Scope 3 (tCO2e) | Scope 3 % |
# |---|---|---|---|---|---|
# | ANTEA FRANCE | 2023 | 1,924.8 | 44.4 | 12,840.8 | 86.7% |
# | ARTELIA | 2022 | 3,365.0 | 981.0 | 17,944.0 | 80.5% |
# | BUREAU VERITAS EXPLOITATION | 2023 | 230.0 | 0.0 | 23,068.0 | 99.0% |
# | ECOCERT SA | 2024 | 565.3 | 12.1 | 3,183.6 | 84.6% |
# | Eco CO2 | 2023 | 26.4 | 1.4 | 1,535.6 | 98.2% |
#
# *Scope 3-equivalent totals include P3, P4, P5, and P6. P6.1 is provisionally treated as corresponding to BEGES posts 15 and 23.*
#
# ---
#
# **Bureau Veritas Exploitation** reports the largest total footprint at 23,298 tCO2e,
# with Scope 3 accounting for 99% of that total. Scope 1 is small relative to total
# emissions, and Scope 2 is reported as zero. For a large inspection and certification
# entity, near-zero Scope 2 is unusual and warrants scrutiny in the methodology audit.
# It may reflect a market-based electricity accounting choice, a consolidation boundary
# issue, incomplete disclosure, or a data entry problem.
#
# **Artelia** reports 22,290 tCO2e total and is the only firm with a clearly visible
# Scope 2 segment (981 tCO2e, 4.4% of total). Artelia also has the lowest Scope 3
# concentration in the dataset at 80.5%. This may suggest a different boundary approach,
# stronger energy reporting completeness, or a higher direct energy consumption profile
# than the others. Their Scope 1 total (3,365 tCO2e) is also the highest in absolute
# terms, possibly reflecting a larger company vehicle fleet. Both figures will be examined
# in notebook 03.
#
# **Antea France** sits in the middle at 14,810 tCO2e, with Scope 3 at 86.7%. Their
# Scope 1 figure (1,925 tCO2e) is significant relative to total emissions and may
# reflect mobile combustion from site investigation fieldwork, consistent with their
# profile as an environmental consulting firm.
#
# **Ecocert SA** reports 3,761 tCO2e total, with Scope 3 at 84.6%, one of the lower
# Scope 3 shares in the dataset. They are also the only firm for which headcount data
# was available in the ADEME export (778 employees), giving a Scope 3 intensity of
# 4.1 tCO2e per employee.
#
# **Eco CO2** is the smallest firm in the dataset, with 1,563.4 tCO2e total reported
# emissions. They are the only firm with a non-zero P6.1 value (21.64 tCO2e). P6.1 is
# inferred to represent posts 15 and 23 based on the structure of the export. This has
# not yet been verified against ADEME metadata or the firm’s free-text methodology fields.
# Their Scope 3-equivalent total is 1,535.6 tCO2e (98.2% of total reported emissions).
# The nature of the P6.1 entry will be examined in notebook 03 when reviewing free-text
# methodology fields.
#
# ---
#
# **Key limitation:** emissions totals reflect only what each firm has chosen to report
# in the structured fields of the ADEME export. A firm with a lower total may have
# excluded more Scope 3 categories rather than genuinely emitting less. Notebook 02
# will assess coverage completeness for each firm and distinguish between categories
# that were reported with a value, reported as zero, or missing from the structured
# emissions fields. Public BEGES data are self-reported and not independently verified unless the
# organisation has voluntarily sought third-party assurance.
